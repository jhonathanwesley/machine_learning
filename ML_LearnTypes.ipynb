# %% [markdown]
# # ***Tipos de Aprendizado***
#
# > [Material de estudo: Curso de Machine Learning - Téo](https://www.youtube.com/playlist?list=PLvlkVRRKOYFR6_LmNcJliicNan2TYeFO2)

# %% [markdown]
# ---

# %% [markdown]
# <div style="text-align: center;">
#     <img src="attachment:e6306b90-a3e3-4546-a3b2-32bf27916b66.png" width="800px">
# </div>
# <!-- ![image.png](attachment:e6306b90-a3e3-4546-a3b2-32bf27916b66.png) -->

# %% [markdown]
# ## **Aprendizado Supervisionado**
#
# > O Aprendizado Supervisionado é quando se tem uma variável resposta.
# > Quando queremos prever uma variável `target`
#
# - É aplicado quando precisamos prever uma variável:
#
# > Pode ser subdividido em:
#
# 1. **_Classificação_**
# 2. **_Regressão_**

# %% [markdown]
# #### **_REGRESSÃO_**
# > Problemas de `REGRESSÃO` são voltados à estimativa alvo ( `target` ), sendo este um número, valor. Por exmplo:
#
# - Quantidade de Vendas
# - Receita presumida
# - Valor de Crédito
# - Precificação de Imóvel
# - Volume de Chuva

# %% [markdown]
# #### **_CLASSIFICAÇÃO_**
#
# > Problemas de `CLASSIFICAÇÃO` são voltado à estimativa alvo ( `target` ), sendo este um **rótulo** ou **classe**, por exemplo:
#
# - <u>Compradores</u> _vs._ <u>Não Compradores</u>
# - <u>Churn</u> _vs._ <u>Não Churn</u>
# - <u>Reconhecimento Facial</u>
# - <u>Inadimplente</u> _vs._ <u>Adimplente</u>
# - <u>Diagnóstico de Câncer</u>
# - <u>Gravidez</u>

# %% [markdown]
# > Diferenciando o **_USO_** dos <u>TIPOS DE APRENDIZADO</u>:
#
# 1. Vai Chover ou Não Vai Chover? : É **_CLASSIFICAÇÃO_**.
# 2. O quanto vai chover? : É _**REGRESSÃO**_.

# %% [markdown]
# ## Aprendizado não Supervisionado
#
# > Não temos uma variável ***alvo*** (**Resposta**)
#
# - É utilizado para entender grupos, perfis entre as variáveis, clusters, reduzir dimensão.
#     1. **Agrupar**

# %% [markdown]
# ---

# %% [markdown]
# ## O Ciclo Analítico
#
# > Se trata do processo de criar a base analítica, como eu estruturo as minhas variáveis, como eu modelo o problema?
#
# - **Analytical Base Table** - `ABT`: A _Analytical Base Table_ representa a entidade que queremos modelar!
# - Após a modelagem da `ABT` é necessário manter um exato mesmo ETL dos dados de origem para manutenção do `input` para o modelo.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="attachment:6b6d8f59-a0e4-45eb-9ff5-809627c84354.png" width="600px">
# </div>
# <!-- ![image.png](attachment:6b6d8f59-a0e4-45eb-9ff5-809627c84354.png) -->

# %% [markdown]
# ## Algoritmos de ***REGRESSÃO LINEAR***
# > É um nodelo estatístico, ou um método estatístico, ou uma função estatística, para fazer a previsão de valores numéricos
#
# - Utiliza a ***DSIPERSÃO*** ( `dispersão` == `spread` ) estre as variáveis.
# - À partir dos meus dados, em função de uma variável independente, será que eu consigo estimar uma variável dependente.
# - Ou seja, x e y, eixos das abcissas e ordenadas, respectivamente.
# - À partir disso temos que:
#     1. f(x) = a + x movimenta a reta no eixo y, muda o valor da variável dependente.
#     2. f(x) = bx inclina a minha reta, alterando o ângulo em relação ao eixo das abcissas, x.
#     3. f(x) = a + bx movimenta em y e inclina em x cada uma das retas da função.
# > Com isso, temos a seguinte pergunta:
# - Dadas as observações das ocorrências dos meus atributos, qual é a melhor reta que posso colocar no gráfico para representar esses pontos? ( Os pontos são os conjuntos de pares ordenados (x,y), as relações entre as minhas variáveis. )
#
# <div style="text-align: center;">
#     <img src="attachment:1d1ae9d7-3057-45f4-a017-b99e82fecf4b.png" alt="Scatter Plot de Exemplo da busca pela reta mais representativa." width="600px">
# </div>
# <!-- ![image.png](attachment:1d1ae9d7-3057-45f4-a017-b99e82fecf4b.png) -->

# %% [markdown]
# ---

# %% [markdown]
# ### Introdução ao ***ERRO*** em modelos
# 1. Ajuste com ***Mínimos Quadrados***
# > Cálculo do `ERRO`
# <div style="text-align: center;">
#     <img src="attachment:d40045b0-f968-4e0e-8011-98cfe00a0482.png" alt="Cálculo do ERRO das retas" width="600px">
# </div>
#
# - O resultado final é o nosso `erro quadrático` summarizado, SEQ ( `Soma do Erro Quadrático` ).
# - Queremos encontrar a reta com a menor **SOMA DO ERRO QUADRÁTICO**.
# <div style="text-align: center;">
#     <img src="attachment:3699f910-c350-4e90-b575-a42939d254b9.png" alt="Cálculo de redução do erro quadrático." width="600px">
# </div>
#
# > Resolvendo o Sistema Linear com Derivação das funções.
# <div style="text-align: center;">
#     <img src="attachment:77f55dae-e45f-4d28-8b94-92b121a8dc0a.png" alt="Reduzindo o erro resolvendo um sistema linear á partir da derivada da função." width="600px">
# </div>
#
# 2. Outros métodos de ajuste além dos mínimos quadrados:
# - ***Método de Máxima Verossimilhança*** ( _Inferência Clássica_ )
# - ***Método Bayesiano*** ( _Inferência Bayesiana_ )
#     - Geralmente, Melhor em bases pequenas, poucas amostras, exemplo, poucas amostras em estudo de vacinas por exemplo.
#
# <!--
#
# -->

# %% [markdown]
# ---

# %% [markdown]
# > Usando mais variáveis:
#
# <div style="text-align: center;">
#     <img src="attachment:59339d84-4604-49fb-9dff-061de162f58a.png" alt="Aplicando mais parâmetros, variáveis no modelo de regressão." width="600px">
# </div>
